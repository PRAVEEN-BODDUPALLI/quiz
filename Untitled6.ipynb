# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load your time series dataset
# For this example, let's use a simple sine wave
data = np.sin(np.arange(0, 100, 0.1))

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data_normalized = scaler.fit_transform(data.reshape(-1, 1))

# Prepare the data for LSTM model
def create_dataset(dataset, time_step=1):
    X, y = [], []
    for i in range(len(dataset)-time_step-1):
        X.append(dataset[i:(i+time_step), 0])
        y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 10
X, y = create_dataset(data_normalized, time_step)

# Reshape input data to be 3D [samples, time steps, features] as required by LSTM
X = X.reshape(X.shape[0], X.shape[1], 1)

# Split the data into training and testing sets
train_size = int(len(X) * 0.7)
test_size = len(X) - train_size
X_train, X_test = X[0:train_size], X[train_size:len(X)]
y_train, y_test = y[0:train_size], y[train_size:len(y)]

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(time_step, 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=64)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform the predictions to original scale
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# Calculate RMSE
train_rmse = np.sqrt(mean_squared_error(scaler.inverse_transform(y_train.reshape(-1, 1)), train_predict))
test_rmse = np.sqrt(mean_squared_error(scaler.inverse_transform(y_test.reshape(-1, 1)), test_predict))
print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)

# Plotting
plt.figure(figsize=(10,6))
plt.plot(data, label='Actual')
plt.plot(np.concatenate([train_predict, test_predict]), label='Predicted')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:From D:\praveenboddupalli\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From D:\praveenboddupalli\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\praveenboddupalli\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From D:\praveenboddupalli\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 11/11 [==============================] - 7s 17ms/step - loss: 0.2088
# Epoch 2/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0552
# Epoch 3/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0427
# Epoch 4/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0387
# Epoch 5/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0362
# Epoch 6/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0332
# Epoch 7/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0304
# Epoch 8/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0282
# Epoch 9/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0245
# Epoch 10/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0199
# Epoch 11/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0140
# Epoch 12/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0069
# Epoch 13/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 14/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0019
# Epoch 15/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0011
# Epoch 16/100
# 11/11 [==============================] - 0s 14ms/step - loss: 7.1617e-04
# Epoch 17/100
# 11/11 [==============================] - 0s 14ms/step - loss: 5.1583e-04
# Epoch 18/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.8115e-04
# Epoch 19/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.1321e-04
# Epoch 20/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.6566e-04
# Epoch 21/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.3523e-04
# Epoch 22/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.3364e-04
# Epoch 23/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.2648e-04
# Epoch 24/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.7934e-04
# Epoch 25/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.2255e-04
# Epoch 26/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.7953e-04
# Epoch 27/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.6505e-04
# Epoch 28/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.6805e-04
# Epoch 29/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.4046e-04
# Epoch 30/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.3911e-04
# Epoch 31/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.5608e-04
# Epoch 32/100
# 11/11 [==============================] - 0s 16ms/step - loss: 1.3929e-04
# Epoch 33/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.6243e-04
# Epoch 34/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.4845e-04
# Epoch 35/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.5619e-04
# Epoch 36/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.4152e-04
# Epoch 37/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.7753e-04
# Epoch 38/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.2336e-04
# Epoch 39/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.4798e-04
# Epoch 40/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.2575e-04
# Epoch 41/100
# 11/11 [==============================] - 0s 17ms/step - loss: 1.4533e-04
# Epoch 42/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.0684e-04
# Epoch 43/100
# 11/11 [==============================] - 0s 15ms/step - loss: 9.6777e-05
# Epoch 44/100
# 11/11 [==============================] - 0s 15ms/step - loss: 7.6743e-05
# Epoch 45/100
# 11/11 [==============================] - 0s 14ms/step - loss: 7.1209e-05
# Epoch 46/100
# 11/11 [==============================] - 0s 14ms/step - loss: 7.4355e-05
# Epoch 47/100
# 11/11 [==============================] - 0s 15ms/step - loss: 6.2049e-05
# Epoch 48/100
# 11/11 [==============================] - 0s 15ms/step - loss: 5.9269e-05
# Epoch 49/100
# 11/11 [==============================] - 0s 15ms/step - loss: 5.0809e-05
# Epoch 50/100
# 11/11 [==============================] - 0s 14ms/step - loss: 4.1222e-05
# Epoch 51/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.7725e-05
# Epoch 52/100
# 11/11 [==============================] - 0s 15ms/step - loss: 3.6557e-05
# Epoch 53/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.4193e-05
# Epoch 54/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.4767e-05
# Epoch 55/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.4792e-05
# Epoch 56/100
# 11/11 [==============================] - 0s 15ms/step - loss: 3.5893e-05
# Epoch 57/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.9023e-05
# Epoch 58/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.9477e-05
# Epoch 59/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.3757e-05
# Epoch 60/100
# 11/11 [==============================] - 0s 15ms/step - loss: 3.6358e-05
# Epoch 61/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.2593e-05
# Epoch 62/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.2488e-05
# Epoch 63/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.0629e-05
# Epoch 64/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.6908e-05
# Epoch 65/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.3635e-05
# Epoch 66/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.8176e-05
# Epoch 67/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.7376e-05
# Epoch 68/100
# 11/11 [==============================] - 0s 16ms/step - loss: 4.0194e-05
# Epoch 69/100
# 11/11 [==============================] - 0s 15ms/step - loss: 3.2406e-05
# Epoch 70/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.6131e-05
# Epoch 71/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.0100e-05
# Epoch 72/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.4584e-05
# Epoch 73/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.7905e-05
# Epoch 74/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.6062e-05
# Epoch 75/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.4337e-05
# Epoch 76/100
# 11/11 [==============================] - 0s 16ms/step - loss: 8.2556e-05
# Epoch 77/100
# 11/11 [==============================] - 0s 15ms/step - loss: 6.9553e-05
# Epoch 78/100
# 11/11 [==============================] - 0s 14ms/step - loss: 5.5046e-05
# Epoch 79/100
# 11/11 [==============================] - 0s 14ms/step - loss: 5.4302e-05
# Epoch 80/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.5940e-05
# Epoch 81/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.9208e-05
# Epoch 82/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.7435e-05
# Epoch 83/100
# 11/11 [==============================] - 0s 14ms/step - loss: 5.6674e-05
# Epoch 84/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2.6991e-05
# Epoch 85/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.3476e-05
# Epoch 86/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.3467e-05
# Epoch 87/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.8890e-05
# Epoch 88/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.1211e-05
# Epoch 89/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.0552e-05
# Epoch 90/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.2478e-05
# Epoch 91/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.0777e-05
# Epoch 92/100
# 11/11 [==============================] - 0s 15ms/step - loss: 1.5577e-05
# Epoch 93/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.7710e-05
# Epoch 94/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.3677e-05
# Epoch 95/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1.4282e-05
# Epoch 96/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.6114e-05
# Epoch 97/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2.0953e-05
# Epoch 98/100
# 11/11 [==============================] - 0s 15ms/step - loss: 7.5122e-05
# Epoch 99/100
# 11/11 [==============================] - 0s 14ms/step - loss: 5.3111e-05
# Epoch 100/100
# 11/11 [==============================] - 0s 14ms/step - loss: 3.0846e-05
# 22/22 [==============================] - 2s 6ms/step
# 10/10 [==============================] - 0s 6ms/step
# Train RMSE: 0.010546501393039993
# Test RMSE: 0.010633180137229904

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
import matplotlib.pyplot as plt

# Step 1: Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Step 2: Preprocess the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# Step 3: Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Step 4: Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Step 5: Train the model
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)
history = model.fit(x_train, y_train, batch_size=64, epochs=10, validation_split=0.2, callbacks=[reduce_lr])

# Step 6: Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)

# Step 7: Hyperparameter Optimization (Grid Search)
# You can perform grid search for hyperparameters like learning rate, batch size, etc. manually or using libraries like scikit-learn.

# Step 8: Visualize Results
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# WARNING:tensorflow:From D:\praveenboddupalli\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 750/750 [==============================] - 16s 19ms/step - loss: 0.1815 - accuracy: 0.9452 - val_loss: 0.0647 - val_accuracy: 0.9803 - lr: 0.0010
# Epoch 2/10
# 750/750 [==============================] - 14s 18ms/step - loss: 0.0547 - accuracy: 0.9830 - val_loss: 0.0545 - val_accuracy: 0.9844 - lr: 0.0010
# Epoch 3/10
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0372 - accuracy: 0.9881 - val_loss: 0.0471 - val_accuracy: 0.9871 - lr: 0.0010
# Epoch 4/10
# 750/750 [==============================] - 13s 18ms/step - loss: 0.0283 - accuracy: 0.9910 - val_loss: 0.0375 - val_accuracy: 0.9893 - lr: 0.0010
# Epoch 5/10
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0202 - accuracy: 0.9940 - val_loss: 0.0452 - val_accuracy: 0.9872 - lr: 0.0010
# Epoch 6/10
# 750/750 [==============================] - 13s 18ms/step - loss: 0.0163 - accuracy: 0.9944 - val_loss: 0.0436 - val_accuracy: 0.9877 - lr: 0.0010
# Epoch 7/10
# 750/750 [==============================] - 13s 18ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0424 - val_accuracy: 0.9884 - lr: 0.0010
# Epoch 8/10
# 750/750 [==============================] - 13s 18ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0333 - val_accuracy: 0.9919 - lr: 2.0000e-04
# Epoch 9/10
# 750/750 [==============================] - 13s 18ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0368 - val_accuracy: 0.9920 - lr: 2.0000e-04
# Epoch 10/10
# 750/750 [==============================] - 13s 17ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0372 - val_accuracy: 0.9923 - lr: 2.0000e-04
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0260 - accuracy: 0.9928
# Test Accuracy: 0.9927999973297119
